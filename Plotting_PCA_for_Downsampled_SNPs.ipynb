# %%
#ANGSD/0.921
#run with Samtools model for genotype likelihoods: -GL 1
#angsd -out geno_plink -nThreads 10 -bam bamfilesall.list -doPlink 2 -doGeno -4 -doPost 1 -doMajorMinor 1 -GL 1 -doCounts 1 -doMaf 2 -postCutoff 0.99  -SNP_pval 1e-6 -geno_minDepth 4

# %%
#plink/1.90b4.9
#plink --tped geno_plink.tped --tfam geno_plink.tfam --thin-count 6700 --make-bed --out geno_plink_filter6700 --allow-extra-chr --pca

# %% [markdown]
# ***Downsampling 6700 SNPs***

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
cat geno_plink_filter6700.eigenvec | sed 's/ /,/'g > geno_plink_filter6700.csv

# %%
df = pd.read_csv("geno_plink_filter6700.csv", header = None)
hs = pd.read_csv("HS.sample.csv")


pcomp = df.drop([0,1], axis=1)

pcomp
# Out:
#           2         3         4         5         6         7         8   \
# 0  -0.106338  0.193933 -0.036889 -0.017393  0.275146  0.199832  0.342143
# 1  -0.102658  0.171255 -0.033865  0.003120  0.184579  0.133670  0.167046
# 2   0.031312  0.239313 -0.002352  0.017803  0.179681  0.061372 -0.039100
# 3   0.055215  0.217098 -0.001501  0.012368  0.146738 -0.007893 -0.071303
# 4   0.026358  0.109280  0.027122 -0.054825  0.019812 -0.042248  0.000835
# 5   0.013738  0.039894 -0.054773 -0.085742 -0.011567 -0.136232 -0.113420
# 6  -0.087545  0.027846  0.208919 -0.045200 -0.055718  0.046602 -0.024866
# 7  -0.299442 -0.132136  0.488837  0.016437 -0.114426  0.141363  0.009364
# 8  -0.299756 -0.223984  0.539912  0.060817 -0.157727  0.130179  0.027571
# 9  -0.019342  0.134143  0.038785 -0.032054 -0.020508 -0.053536 -0.108361
# 10  0.026497  0.138883 -0.001999 -0.013703  0.036575 -0.035640  0.009015
# 11  0.280653 -0.274877  0.051889  0.036604  0.081119  0.005371  0.147646
# ...

# %%
merged = pd.concat([pcomp, hs], axis=1)

# %%
merged
# Out:
#            2         3         4         5         6         7         8  \
# 0  -0.106338  0.193933 -0.036889 -0.017393  0.275146  0.199832  0.342143
# 1  -0.102658  0.171255 -0.033865  0.003120  0.184579  0.133670  0.167046
# 2   0.031312  0.239313 -0.002352  0.017803  0.179681  0.061372 -0.039100
# 3   0.055215  0.217098 -0.001501  0.012368  0.146738 -0.007893 -0.071303
# 4   0.026358  0.109280  0.027122 -0.054825  0.019812 -0.042248  0.000835
# 5   0.013738  0.039894 -0.054773 -0.085742 -0.011567 -0.136232 -0.113420
# 6  -0.087545  0.027846  0.208919 -0.045200 -0.055718  0.046602 -0.024866
# 7  -0.299442 -0.132136  0.488837  0.016437 -0.114426  0.141363  0.009364
# 8  -0.299756 -0.223984  0.539912  0.060817 -0.157727  0.130179  0.027571
# 9  -0.019342  0.134143  0.038785 -0.032054 -0.020508 -0.053536 -0.108361
# 10  0.026497  0.138883 -0.001999 -0.013703  0.036575 -0.035640  0.009015
# 11  0.280653 -0.274877  0.051889  0.036604  0.081119  0.005371  0.147646
# ...

# %%
merged['popinfo']
PC1 = merged.iloc[:, 2]
PC2 = merged.iloc[:, 3]


merged_n = merged.rename(columns={2: 'PC1'})
merged_new = merged_n.rename(columns={3: 'PC2'})

merged2 =  merged_new.rename(columns={'popinfo': 'Populations'})

# %%
merged2
# Out:
#          PC1       PC2         4         5         6         7         8  \
# 0  -0.106338  0.193933 -0.036889 -0.017393  0.275146  0.199832  0.342143
# 1  -0.102658  0.171255 -0.033865  0.003120  0.184579  0.133670  0.167046
# 2   0.031312  0.239313 -0.002352  0.017803  0.179681  0.061372 -0.039100
# 3   0.055215  0.217098 -0.001501  0.012368  0.146738 -0.007893 -0.071303
# 4   0.026358  0.109280  0.027122 -0.054825  0.019812 -0.042248  0.000835
# 5   0.013738  0.039894 -0.054773 -0.085742 -0.011567 -0.136232 -0.113420
# 6  -0.087545  0.027846  0.208919 -0.045200 -0.055718  0.046602 -0.024866
# 7  -0.299442 -0.132136  0.488837  0.016437 -0.114426  0.141363  0.009364
# 8  -0.299756 -0.223984  0.539912  0.060817 -0.157727  0.130179  0.027571
# 9  -0.019342  0.134143  0.038785 -0.032054 -0.020508 -0.053536 -0.108361
# 10  0.026497  0.138883 -0.001999 -0.013703  0.036575 -0.035640  0.009015
# 11  0.280653 -0.274877  0.051889  0.036604  0.081119  0.005371  0.147646
# ...

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

	
# Set theme
sns.set_style('darkgrid')

colours = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#EE99AC',  # Fairy
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# %%
from matplotlib import pyplot
import seaborn


sns.relplot(x="PC1", y="PC2", data=merged2, hue="Populations", palette=colours, s=(150),height=8, aspect=1)

# %% [markdown]
# ***Downsampling 15,000 SNPs***

# %%
cat geno_plink_filter15000.eigenvec | sed 's/ /,/'g > geno_plink_filter15000.csv

# %%
df = pd.read_csv("geno_plink_filter15000.csv", header = None)
hs = pd.read_csv("HS.sample.csv")


pcomp = df.drop([0,1], axis=1)

# %%
merged = pd.concat([pcomp, hs], axis=1)

# %%
merged['popinfo']
PC1 = merged.iloc[:, 2]
PC2 = merged.iloc[:, 3]


merged_n = merged.rename(columns={2: 'PC1'})
merged_new = merged_n.rename(columns={3: 'PC2'})

merged2 =  merged_new.rename(columns={'popinfo': 'Populations'})

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

	
# Set theme
sns.set_style('darkgrid')

colours = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#EE99AC',  # Fairy
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# %%
from matplotlib import pyplot
import seaborn


sns.relplot(x="PC1", y="PC2", data=merged2, hue="Populations", palette=colours, s=(150),height=8, aspect=1)

# %% [markdown]
# ***Downsampling 2000 SNPs***

# %%
cat geno_plink_filter2000.eigenvec | sed 's/ /,/'g > geno_plink_filter2000.csv

# %%
df = pd.read_csv("geno_plink_filter2000.csv", header = None)
hs = pd.read_csv("HS.sample.csv")


pcomp = df.drop([0,1], axis=1)

# %%
merged = pd.concat([pcomp, hs], axis=1)

# %%
merged['popinfo']
PC1 = merged.iloc[:, 2]
PC2 = merged.iloc[:, 3]


merged_n = merged.rename(columns={2: 'PC1'})
merged_new = merged_n.rename(columns={3: 'PC2'})

merged2 =  merged_new.rename(columns={'popinfo': 'Populations'})

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

	
# Set theme
sns.set_style('darkgrid')

colours = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#EE99AC',  # Fairy
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# %%
from matplotlib import pyplot
import seaborn


sns.relplot(x="PC1", y="PC2", data=merged2, hue="Populations", palette=colours, s=(150),height=8, aspect=1)

# %% [markdown]
# ***Downsampling 1400 SNPs***

# %%
cat geno_plink_filter1400.eigenvec | sed 's/ /,/'g > geno_plink_filter1400.csv

# %%
df = pd.read_csv("geno_plink_filter1400.csv", header = None)
hs = pd.read_csv("HS.sample.csv")


pcomp = df.drop([0,1], axis=1)

# %%
merged = pd.concat([pcomp, hs], axis=1)

# %%
merged['popinfo']
PC1 = merged.iloc[:, 2]
PC2 = merged.iloc[:, 3]


merged_n = merged.rename(columns={2: 'PC1'})
merged_new = merged_n.rename(columns={3: 'PC2'})

merged2 =  merged_new.rename(columns={'popinfo': 'Populations'})

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

	
# Set theme
sns.set_style('darkgrid')

colours = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#EE99AC',  # Fairy
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# %%
from matplotlib import pyplot
import seaborn


sns.relplot(x="PC1", y="PC2", data=merged2, hue="Populations", palette=colours, s=(150),height=8, aspect=1)

# %% [markdown]
# ***Downsampling 300 SNPs***

# %%
cat geno_plink_filter300.eigenvec | sed 's/ /,/'g > geno_plink_filter300.csv

# %%
df = pd.read_csv("geno_plink_filter300.csv", header = None)
hs = pd.read_csv("HS.sample.csv")


pcomp = df.drop([0,1], axis=1)

# %%
merged = pd.concat([pcomp, hs], axis=1)

# %%
merged['popinfo']
PC1 = merged.iloc[:, 2]
PC2 = merged.iloc[:, 3]


merged_n = merged.rename(columns={2: 'PC1'})
merged_new = merged_n.rename(columns={3: 'PC2'})

merged2 =  merged_new.rename(columns={'popinfo': 'Populations'})

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

	
# Set theme
sns.set_style('darkgrid')

colours = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#EE99AC',  # Fairy
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# %%
from matplotlib import pyplot
import seaborn


sns.relplot(x="PC1", y="PC2", data=merged2, hue="Populations", palette=colours, s=(150),height=8, aspect=1)

# %% [markdown]
# ***Downsampling 20 SNPs***

# %%
cat geno_plink_filter20.eigenvec | sed 's/ /,/'g > geno_plink_filter20.csv

# %%
df = pd.read_csv("geno_plink_filter20.csv", header = None)
hs = pd.read_csv("HS.sample.csv")


pcomp = df.drop([0,1], axis=1)

# %%
merged = pd.concat([pcomp, hs], axis=1)

# %%
merged['popinfo']
PC1 = merged.iloc[:, 2]
PC2 = merged.iloc[:, 3]


merged_n = merged.rename(columns={2: 'PC1'})
merged_new = merged_n.rename(columns={3: 'PC2'})

merged2 =  merged_new.rename(columns={'popinfo': 'Populations'})

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

	
# Set theme
sns.set_style('darkgrid')

colours = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#EE99AC',  # Fairy
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# %%
from matplotlib import pyplot
import seaborn


sns.relplot(x="PC1", y="PC2", data=merged2, hue="Populations", palette=colours, s=(150),height=8, aspect=1)
